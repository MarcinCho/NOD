# %% [markdown]
# Import wymaganych bibliotek

# %% [markdown]
# # **Laboratorium 2** - Podstawowe operacje arytmetyczne w analizie danych

# %%
import pandas as pd
import numpy as np
import matplotlib as mat
import plotly as pl
import kagglehub
from kagglehub import KaggleDatasetAdapter
import json
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib as mat
#       4 import plotly as pl
#       5 import kagglehub
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
DATASET_HANDLE = "open-powerlifting/powerlifting-database"

df = df = kagglehub.dataset_load(DATA)


data_set_path = "XAU_15m_data.csv"
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "novandraanugrah/xauusd-gold-price-historical-data-2004-2024",
    data_set_path,
    pandas_kwargs={"delimiter" : ";"}
)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 DATASET_HANDLE = "open-powerlifting/powerlifting-database"
# ----> 3 df = df = kagglehub.dataset_load(DATASET_HANDLE)
#       5 df.head()
#
# NameError: name 'kagglehub' is not defined

# %% [markdown]
# Poodstawowe operacje matematyczne na zbiorze danych:
#
# 2.1. Średnia arytmetyczna
#
# ![image.png](data:image/png;base64,...)

# %%
np.max(df["High"])

# %%
np.min(df["High"])

# %%
np.mean(df["High"])

# %% [markdown]
# 2.2. Mediana
#
# ![image.png](data:image/png;base64,...)

# %%
len(df["High"])

# %%
np.median(df["High"])

# %% [markdown]
# 2.3. Odchylenie standardowe
#
# ![image.png](data:image/png;base64,...)

# %%
np.std(df["High"])

# %% [markdown]
# 2.4. Wariancja
#
# ![image.png](data:image/png;base64,...)

# %%
np.var(df["High"])

# %% [markdown]
# 2.5. Korelacja
#
# ![image.png](data:image/png;base64,...)

# %%
np.corrcoef(df["High"], df["Low"])[0,1]

# %% [markdown]
# 2.6. Kowariancja
#
# ![image.png](data:image/png;base64,...)

# %%
covariance = np.cov(df["High"], df["Low"])
covariance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.corrcoef(df["High"], df["Low"])[0,1]

# %%
corelation = covariance[0,1] / (np.sqrt(covariance[0,0]) * np.sqrt(covariance[1,1]))
corelation
